# %% [markdown]
# # Review drift: is quality changing

# %%
from importlib.util import find_spec

if find_spec('evidently') is None:
    # !pip install git+https://github.com/evidentlyai/evidently.git
# Out:
# Collecting git+https://github.com/evidentlyai/evidently.git
#   Cloning https://github.com/evidentlyai/evidently.git to /private/var/folders/qq/gdppvj912kv3ds7_xnf0q_fc0000gn/T/pip-req-build-3jcy3m55
#   Running command git clone --filter=blob:none --quiet https://github.com/evidentlyai/evidently.git /private/var/folders/qq/gdppvj912kv3ds7_xnf0q_fc0000gn/T/pip-req-build-3jcy3m55
#   Resolved https://github.com/evidentlyai/evidently.git to commit 5e0267aaa09aaf4a807e6601a1cdf0711bd6945e
#   Preparing metadata (setup.py) ... done
# Collecting plotly>=5.10.0
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 93.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: statsmodels>=0.12.2 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (0.13.5)
# Requirement already satisfied: scikit-learn<1.6.0,>=1.0.1 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (1.2.1)
# Requirement already satisfied: pandas[parquet]>=1.3.5 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (2.1.3)
# Requirement already satisfied: numpy<2.1,>=1.22.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (1.26.4)
# Requirement already satisfied: nltk>=3.6.7 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (3.8.1)
# Requirement already satisfied: scipy>=1.10.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (1.12.0)
# Requirement already satisfied: requests>=2.32.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (2.32.3)
# Requirement already satisfied: PyYAML>=5.4 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (6.0.1)
# Requirement already satisfied: pydantic>=1.10.13 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (2.9.2)
# Collecting litestar>=2.8.3
#   Downloading litestar-2.14.0-py3-none-any.whl (567 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.6/567.6 kB 57.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (0.9.0)
# Collecting uvicorn[standard]>=0.22.0
#   Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: watchdog>=3.0.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (4.0.1)
# Requirement already satisfied: typer>=0.3 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (0.4.1)
# Requirement already satisfied: rich>=13 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (13.7.1)
# Collecting iterative-telemetry>=0.0.5
#   Downloading iterative_telemetry-0.0.9-py3-none-any.whl (10 kB)
# Collecting dynaconf>=3.2.4
#   Downloading dynaconf-3.2.6-py2.py3-none-any.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2024.7.4 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (2024.8.30)
# Requirement already satisfied: urllib3>=1.26.19 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (1.26.19)
# Requirement already satisfied: fsspec>=2024.6.1 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (2024.6.1)
# Requirement already satisfied: ujson>=5.4.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from evidently==0.5.1) (5.10.0)
# Collecting deprecation>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting uuid6>=2024.7.10
#   Downloading uuid6-2024.7.10-py3-none-any.whl (6.4 kB)
# Collecting cryptography>=43.0.1
#   Downloading cryptography-44.0.0-cp39-abi3-macosx_10_9_universal2.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 110.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: cffi>=1.12 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from cryptography>=43.0.1->evidently==0.5.1) (1.17.1)
# Requirement already satisfied: packaging in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from deprecation>=2.1.0->evidently==0.5.1) (24.1)
# Requirement already satisfied: appdirs in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.5.1) (1.4.4)
# Requirement already satisfied: distro in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.5.1) (1.8.0)
# Requirement already satisfied: filelock in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.5.1) (3.13.1)
# Requirement already satisfied: exceptiongroup in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.5.1) (1.2.0)
# Collecting rich-click
#   Downloading rich_click-1.8.5-py3-none-any.whl (35 kB)
# Requirement already satisfied: typing-extensions in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.5.1) (4.11.0)
# Requirement already satisfied: anyio>=3 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.5.1) (3.5.0)
# Collecting litestar-htmx>=0.4.0
#   Downloading litestar_htmx-0.4.1-py3-none-any.whl (10.0 kB)
# Collecting msgspec>=0.18.2
#   Downloading msgspec-0.19.0-cp310-cp310-macosx_11_0_arm64.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.7/183.7 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.5.1) (8.0.4)
# Collecting multipart>=1.2.0
#   Downloading multipart-1.2.1-py3-none-any.whl (13 kB)
# Collecting polyfactory>=2.6.3
#   Downloading polyfactory-2.18.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: httpx>=0.22 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.5.1) (0.27.2)
# Requirement already satisfied: multidict>=6.0.2 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.5.1) (6.0.4)
# Requirement already satisfied: tqdm in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.5.1) (4.66.5)
# Requirement already satisfied: regex>=2021.8.3 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.5.1) (2022.7.9)
# Requirement already satisfied: joblib in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.5.1) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.5.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.5.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.5.1) (2023.3)
# Requirement already satisfied: pyarrow>=7.0.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.5.1) (11.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from plotly>=5.10.0->evidently==0.5.1) (8.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.5.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.5.1) (2.23.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.5.1) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.5.1) (3.3.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from rich>=13->evidently==0.5.1) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from rich>=13->evidently==0.5.1) (2.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from scikit-learn<1.6.0,>=1.0.1->evidently==0.5.1) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently==0.5.1) (0.5.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently==0.5.1) (1.0.0)
# Requirement already satisfied: h11>=0.8 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.5.1) (0.14.0)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.21.0-cp310-cp310-macosx_10_9_universal2.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 86.3 MB/s eta 0:00:00
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp310-cp310-macosx_11_0_arm64.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv>=0.13 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.5.1) (0.21.0)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.0.3-cp310-cp310-macosx_11_0_arm64.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.8/384.8 kB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: websockets>=10.4 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.5.1) (10.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.5.1) (1.3.0)
# Requirement already satisfied: pycparser in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=43.0.1->evidently==0.5.1) (2.21)
# Requirement already satisfied: httpcore==1.* in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.5.1) (1.0.5)
# Requirement already satisfied: mdurl~=0.1 in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.5.1) (0.1.2)
# Requirement already satisfied: six in /Users/aus10powell/anaconda3/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.12.2->evidently==0.5.1) (1.16.0)
# Collecting faker
#   Downloading Faker-33.3.0-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 96.2 MB/s eta 0:00:00
# Building wheels for collected packages: evidently
#   Building wheel for evidently (setup.py) ... done
#   Created wheel for evidently: filename=evidently-0.5.1-py3-none-any.whl size=3462998 sha256=12cb27654c681530df2abc99372137fe2bdb508083577d095603b5ed95e94c22
#   Stored in directory: /private/var/folders/qq/gdppvj912kv3ds7_xnf0q_fc0000gn/T/pip-ephem-wheel-cache-9z59jgsd/wheels/b9/63/7b/170638c7d0b5772f1e76c1d9adefc91eee2697a23b337135e0
# Successfully built evidently
# Installing collected packages: uvloop, uvicorn, uuid6, plotly, multipart, msgspec, litestar-htmx, httptools, dynaconf, deprecation, watchfiles, iterative-telemetry, faker, cryptography, rich-click, polyfactory, litestar, evidently
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Uninstalling plotly-5.9.0:
#       Successfully uninstalled plotly-5.9.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.0
#     Uninstalling cryptography-43.0.0:
#       Successfully uninstalled cryptography-43.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 44.0.0 which is incompatible.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.9.2 which is incompatible.
# anaconda-cloud-auth 0.1.4 requires semver<3, but you have semver 3.0.1 which is incompatible.
# Successfully installed cryptography-44.0.0 deprecation-2.1.0 dynaconf-3.2.6 evidently-0.5.1 faker-33.3.0 httptools-0.6.4 iterative-telemetry-0.0.9 litestar-2.14.0 litestar-htmx-0.4.1 msgspec-0.19.0 multipart-1.2.1 plotly-5.24.1 polyfactory-2.18.1 rich-click-1.8.5 uuid6-2024.7.10 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.3

# %%
import pandas as pd
import numpy as np
import requests
import zipfile
import io

from datetime import datetime, time
from sklearn import datasets, ensemble

from evidently import ColumnMapping
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# ## Import data

# %% [markdown]
# ### Reviews data

# %%
import os

DATA_DIR = '../data/'

# List contents of the data directory
if os.path.exists(DATA_DIR):
    files = os.listdir(DATA_DIR)
    print("Files in data directory:")
    for file in files:
        print(f" - {file}")
else:
    print(f"Directory {DATA_DIR} does not exist")


# Load oakland reviews
df_r = pd.read_csv(os.path.join(DATA_DIR, 'airbnb_oakland_reviews.csv'))
print(f'shape: {df_r.shape}')
display(df_r.head())
# Out:
# Files in data directory:
#  - airbnb_oakland_reviews.csv
# shape: (126603, 6)
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        3083  16797662  2014-08-02     18272366  Carlos Kenji
# 1        3083  19980893  2014-09-21      4400249         Jason
# 2        3083  21720882  2014-10-22      4268642        Carmen
# 3        3083  27107155  2015-02-25     23674350       Matthew
# 4        3083  33318077  2015-05-26      1252519         Pavel
#
#                                             comments
# 0  B- love guest house is a pretty good place, ev...
# 1  The description was accurate, B was very nice ...
# 2  B-Love makes me feel at home since she open th...
# 3  Simple but effective. Very close to the city a...
# 4  I enjoyed staying in Tracy's guesthouse! Her a...

# %%
# Pick a listing_id by number of reviews and date range
df_r['date'] = pd.to_datetime(df_r['date'])

# Get counts of reviews per listing
counts = df_r.groupby('listing_id').size().sort_values(ascending=False).rename('count').reset_index()

# Calculate date range, but flatten the multi-level columns
days = (df_r.groupby('listing_id')
        .agg({'date': lambda x: (x.max() - x.min()).days})
        .rename(columns={'date': 'days_between'})
        .reset_index())

# Now merge will work correctly
merged_df = pd.merge(counts, days, on='listing_id')

# Display results
print("Review counts per listing:")
print(counts.head())
print("\nDays between first and last review:")
print(days.head())
print("\nMerged results:")
display(merged_df.head())


# Have a view of which listing maybe a good candidate
display(merged_df.sort_values(['count', 'days_between'], ascending=[False, True], inplace=True))
# Out:
# Review counts per listing:
#    listing_id  count
# 0    21632573    877
# 1    41325003    798
# 2     1615052    777
# 3    24498215    732
# 4     1673795    726
#
# Days between first and last review:
#    listing_id  days_between
# 0        3083          3681
# 1        5739          5526
# 2       23637          4546
# 3       24916          5137
# 4       29521          4775
#
# Merged results:
#    listing_id  count  days_between
# 0    21632573    877          2483
# 1    41325003    798          1714
# 2     1615052    777          3991
# 3    24498215    732          2331
# 4     1673795    726          3960
# None

# %% [markdown]
# ### Ratings Data
